# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from gtts import gTTS 
from IPython.display import Audio 
tts = gTTS('halika dito') 
tts.save('1.wav') 
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts = gTTS('Machine Learning') 
tts.save('2.wav') 
sound_file1 = '2.wav'
Audio(sound_file1, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts = gTTS('Cebu Pacific is ending the summer season with an P88 one-way base fares to all its domestic routes. From Manila, you can go to a local destination you’ve been dreaming to visit such as Puerto Princesa, Boracay, Iloilo, Siargao, Coron, Bohol, Cebu, and so much more.') 
tts.save('3.wav') 
sound_file2 = '3.wav'
Audio(sound_file2, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
